# %% [markdown]
# ## Is it a bird?

# %%
#NB: Kaggle requires phone verification to use the internet or a GPU. If you haven't done that yet, the cell below will fail
#    This code is only here to check that your internet is enabled. It doesn't do anything else.
#    Here's a help thread on getting your phone number verified: https://www.kaggle.com/product-feedback/135367

import socket,warnings
try:
    socket.setdefaulttimeout(1)
    socket.socket(socket.AF_INET, socket.SOCK_STREAM).connect(('1.1.1.1', 53))
except socket.error as ex: raise Exception("STOP: No internet. Click '>|' in top right and set 'Internet' switch to on")

# %%
# It's a good idea to ensure you're running the latest version of any libraries you need.
# `!pip install -Uqq <libraries>` upgrades to the latest version of <libraries>
# NB: You can safely ignore any warnings or errors pip spits out about running as root or incompatibilities
import os
iskaggle = os.environ.get('KAGGLE_KERNEL_RUN_TYPE', '')
print(f'iskaggle')
#if iskaggle:
# !pip install -U duckduckgo_search
# !pip install fastai
# !pip install fastbook
# Out:
# iskaggle
# Requirement already satisfied: duckduckgo_search in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (4.1.0)
# Requirement already satisfied: click>=8.1.7 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from duckduckgo_search) (8.1.7)
# Requirement already satisfied: lxml>=4.9.3 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from duckduckgo_search) (4.9.4)
# Requirement already satisfied: curl-cffi>=0.5.10 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from duckduckgo_search) (0.5.10)
# Requirement already satisfied: cffi>=1.12.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from curl-cffi>=0.5.10->duckduckgo_search) (1.16.0)
# Requirement already satisfied: pycparser in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from cffi>=1.12.0->curl-cffi>=0.5.10->duckduckgo_search) (2.21)
# Requirement already satisfied: fastai in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (2.7.13)
# Requirement already satisfied: pip in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastai) (23.3.1)
# Requirement already satisfied: packaging in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastai) (23.1)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastai) (0.0.7)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastai) (1.5.29)
# Requirement already satisfied: torchvision>=0.11 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastai) (0.15.2a0)
# Requirement already satisfied: matplotlib in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastai) (3.8.0)
# Requirement already satisfied: pandas in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastai) (2.1.4)
# Requirement already satisfied: requests in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastai) (2.31.0)
# Requirement already satisfied: pyyaml in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastai) (6.0.1)
# Requirement already satisfied: fastprogress>=0.2.4 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastai) (1.0.3)
# Requirement already satisfied: pillow>=9.0.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastai) (10.0.1)
# Requirement already satisfied: scikit-learn in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastai) (1.3.0)
# Requirement already satisfied: scipy in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastai) (1.11.4)
# Requirement already satisfied: spacy<4 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastai) (3.5.3)
# Requirement already satisfied: torch<2.2,>=1.10 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastai) (2.1.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai) (1.0.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai) (2.0.10)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai) (0.4.1)
# Requirement already satisfied: pathy>=0.10.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai) (1.24.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai) (1.10.12)
# Requirement already satisfied: jinja2 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai) (3.1.2)
# Requirement already satisfied: setuptools in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai) (68.2.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai) (3.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from requests->fastai) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from requests->fastai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from requests->fastai) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from requests->fastai) (2023.11.17)
# Requirement already satisfied: filelock in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai) (3.13.1)
# Requirement already satisfied: typing-extensions in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai) (4.7.1)
# Requirement already satisfied: sympy in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai) (1.12)
# Requirement already satisfied: networkx in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai) (3.1)
# Requirement already satisfied: fsspec in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<2.2,>=1.10->fastai) (12.3.101)
# Requirement already satisfied: contourpy>=1.0.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from matplotlib->fastai) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from matplotlib->fastai) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from matplotlib->fastai) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from matplotlib->fastai) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from matplotlib->fastai) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from matplotlib->fastai) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from pandas->fastai) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from pandas->fastai) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from scikit-learn->fastai) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from scikit-learn->fastai) (2.2.0)
# Requirement already satisfied: six>=1.5 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->fastai) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy<4->fastai) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy<4->fastai) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from typer<0.8.0,>=0.3.0->spacy<4->fastai) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jinja2->spacy<4->fastai) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from sympy->torch<2.2,>=1.10->fastai) (1.3.0)
# Requirement already satisfied: fastbook in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (0.0.29)
# Requirement already satisfied: pip in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastbook) (23.3.1)
# Requirement already satisfied: packaging in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastbook) (23.1)
# Requirement already satisfied: fastai>=2.6 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastbook) (2.7.13)
# Requirement already satisfied: graphviz in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastbook) (0.20.1)
# Requirement already satisfied: pandas in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastbook) (2.1.4)
# Requirement already satisfied: requests in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastbook) (2.31.0)
# Requirement already satisfied: transformers in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastbook) (4.36.2)
# Requirement already satisfied: datasets in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastbook) (2.15.0)
# Requirement already satisfied: ipywidgets<8 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastbook) (7.8.1)
# Requirement already satisfied: sentencepiece in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastbook) (0.1.99)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastai>=2.6->fastbook) (0.0.7)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastai>=2.6->fastbook) (1.5.29)
# Requirement already satisfied: torchvision>=0.11 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastai>=2.6->fastbook) (0.15.2a0)
# Requirement already satisfied: matplotlib in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastai>=2.6->fastbook) (3.8.0)
# Requirement already satisfied: pyyaml in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastai>=2.6->fastbook) (6.0.1)
# Requirement already satisfied: fastprogress>=0.2.4 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastai>=2.6->fastbook) (1.0.3)
# Requirement already satisfied: pillow>=9.0.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastai>=2.6->fastbook) (10.0.1)
# Requirement already satisfied: scikit-learn in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastai>=2.6->fastbook) (1.3.0)
# Requirement already satisfied: scipy in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastai>=2.6->fastbook) (1.11.4)
# Requirement already satisfied: spacy<4 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastai>=2.6->fastbook) (3.5.3)
# Requirement already satisfied: torch<2.2,>=1.10 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fastai>=2.6->fastbook) (2.1.2)
# Requirement already satisfied: comm>=0.1.3 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from ipywidgets<8->fastbook) (0.2.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from ipywidgets<8->fastbook) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from ipywidgets<8->fastbook) (5.14.0)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from ipywidgets<8->fastbook) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from ipywidgets<8->fastbook) (8.18.1)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from ipywidgets<8->fastbook) (1.1.7)
# Requirement already satisfied: numpy>=1.17 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from datasets->fastbook) (1.24.3)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from datasets->fastbook) (11.0.0)
# Requirement already satisfied: pyarrow-hotfix in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from datasets->fastbook) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from datasets->fastbook) (0.3.7)
# Requirement already satisfied: tqdm>=4.62.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from datasets->fastbook) (4.65.0)
# Requirement already satisfied: xxhash in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from datasets->fastbook) (3.4.1)
# Requirement already satisfied: multiprocess in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from datasets->fastbook) (0.70.15)
# Requirement already satisfied: fsspec<=2023.10.0,>=2023.1.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets->fastbook) (2023.10.0)
# Requirement already satisfied: aiohttp in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from datasets->fastbook) (3.9.0)
# Requirement already satisfied: huggingface-hub>=0.18.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from datasets->fastbook) (0.19.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from requests->fastbook) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from requests->fastbook) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from requests->fastbook) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from requests->fastbook) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from pandas->fastbook) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from pandas->fastbook) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from pandas->fastbook) (2023.3)
# Requirement already satisfied: filelock in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from transformers->fastbook) (3.13.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from transformers->fastbook) (2023.10.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from transformers->fastbook) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from transformers->fastbook) (0.4.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from aiohttp->datasets->fastbook) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from aiohttp->datasets->fastbook) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from aiohttp->datasets->fastbook) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from aiohttp->datasets->fastbook) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from aiohttp->datasets->fastbook) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from huggingface-hub>=0.18.0->datasets->fastbook) (4.7.1)
# Requirement already satisfied: decorator in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (2.17.2)
# Requirement already satisfied: stack-data in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (4.9.0)
# Requirement already satisfied: six>=1.5 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->fastbook) (1.16.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai>=2.6->fastbook) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai>=2.6->fastbook) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai>=2.6->fastbook) (1.0.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai>=2.6->fastbook) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai>=2.6->fastbook) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai>=2.6->fastbook) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai>=2.6->fastbook) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai>=2.6->fastbook) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai>=2.6->fastbook) (2.0.10)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai>=2.6->fastbook) (0.4.1)
# Requirement already satisfied: pathy>=0.10.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai>=2.6->fastbook) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai>=2.6->fastbook) (5.2.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai>=2.6->fastbook) (1.10.12)
# Requirement already satisfied: jinja2 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai>=2.6->fastbook) (3.1.2)
# Requirement already satisfied: setuptools in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai>=2.6->fastbook) (68.2.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from spacy<4->fastai>=2.6->fastbook) (3.3.0)
# Requirement already satisfied: sympy in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai>=2.6->fastbook) (1.12)
# Requirement already satisfied: networkx in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai>=2.6->fastbook) (3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai>=2.6->fastbook) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai>=2.6->fastbook) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai>=2.6->fastbook) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai>=2.6->fastbook) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai>=2.6->fastbook) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai>=2.6->fastbook) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai>=2.6->fastbook) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai>=2.6->fastbook) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai>=2.6->fastbook) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai>=2.6->fastbook) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai>=2.6->fastbook) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from torch<2.2,>=1.10->fastai>=2.6->fastbook) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<2.2,>=1.10->fastai>=2.6->fastbook) (12.3.101)
# Requirement already satisfied: notebook>=4.4.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (7.0.6)
# Requirement already satisfied: contourpy>=1.0.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from matplotlib->fastai>=2.6->fastbook) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from matplotlib->fastai>=2.6->fastbook) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from matplotlib->fastai>=2.6->fastbook) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from matplotlib->fastai>=2.6->fastbook) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from matplotlib->fastai>=2.6->fastbook) (3.0.9)
# Requirement already satisfied: joblib>=1.1.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from scikit-learn->fastai>=2.6->fastbook) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from scikit-learn->fastai>=2.6->fastbook) (2.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8->fastbook) (0.8.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (2.12.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (2.25.2)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (4.0.9)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (6.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8->fastbook) (0.7.0)
# Requirement already satisfied: wcwidth in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets<8->fastbook) (0.2.12)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy<4->fastai>=2.6->fastbook) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from thinc<8.2.0,>=8.1.8->spacy<4->fastai>=2.6->fastbook) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from typer<0.8.0,>=0.3.0->spacy<4->fastai>=2.6->fastbook) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jinja2->spacy<4->fastai>=2.6->fastbook) (2.1.3)
# Requirement already satisfied: executing>=1.2.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8->fastbook) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8->fastbook) (2.4.1)
# Requirement already satisfied: pure-eval in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8->fastbook) (0.2.2)
# Requirement already satisfied: mpmath>=0.19 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from sympy->torch<2.2,>=1.10->fastai>=2.6->fastbook) (1.3.0)
# Requirement already satisfied: anyio>=3.1.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (4.2.0)
# Requirement already satisfied: argon2-cffi in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (23.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (5.5.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.9.0)
# Requirement already satisfied: jupyter-server-terminals in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.5.0)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (7.13.0)
# Requirement already satisfied: nbformat>=5.3.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (5.9.2)
# Requirement already satisfied: overrides in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (7.4.0)
# Requirement already satisfied: prometheus-client in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.19.0)
# Requirement already satisfied: pyzmq>=24 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.18.0)
# Requirement already satisfied: websocket-client in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (1.7.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (2.0.4)
# Requirement already satisfied: ipykernel in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (6.27.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (2.2.1)
# Requirement already satisfied: babel>=2.10 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (2.14.0)
# Requirement already satisfied: json5>=0.9.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.9.14)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (4.20.0)
# Requirement already satisfied: sniffio>=1.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (1.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.32.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.15.2)
# Requirement already satisfied: platformdirs>=2.5 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (3.10.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (6.1.0)
# Requirement already satisfied: defusedxml in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.9.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (1.5.0)
# Requirement already satisfied: tinycss2 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (1.2.1)
# Requirement already satisfied: fastjsonschema in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (2.19.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (21.2.0)
# Requirement already satisfied: debugpy>=1.6.5 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (1.8.0)
# Requirement already satisfied: nest-asyncio in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (1.5.8)
# Requirement already satisfied: psutil in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (5.9.7)
# Requirement already satisfied: webencodings in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.5.1)
# Requirement already satisfied: fqdn in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (1.5.1)
# Requirement already satisfied: isoduration in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (2.1)
# Requirement already satisfied: uri-template in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (2.5)
# Requirement already satisfied: pycparser in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/asthanaamish/miniconda3/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (2.8.19.14)

# %% [markdown]
# In 2015 the idea of creating a computer system that could recognise birds was considered so outrageously challenging that it was the basis of [this XKCD joke](https://xkcd.com/1425/):

# %% [markdown]
# ![image.png](attachment:a0483178-c30e-4fdd-b2c2-349e130ab260.png)

# %% [markdown]
# But today, we can do exactly that, in just a few minutes, using entirely free resources!
#
# The basic steps we'll take are:
#
# 1. Use DuckDuckGo to search for images of "bird photos"
# 1. Use DuckDuckGo to search for images of "forest photos"
# 1. Fine-tune a pretrained neural network to recognise these two groups
# 1. Try running this model on a picture of a bird and see if it works.

# %% [markdown]
# ## Step 1: Download images of birds and non-birds

# %%
from fastai.vision.widgets import *
from fastbook import *

def search_images(term, max_images=30):
    print(f"Searching for '{term}'")
    return L(search_images_ddg(term, max_images=max_images))
# Out:
# /home/asthanaamish/miniconda3/lib/python3.11/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: 'libc10_cuda.so: cannot open shared object file: No such file or directory'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %% [markdown]
# Let's start by searching for a bird photo and seeing what kind of result we get. We'll start by getting URLs from a search:

# %%
#NB: `search_images` depends on duckduckgo.com, which doesn't always return correct responses.
#    If you get a JSON error, just try running it again (it may take a couple of tries).
urls = search_images('bird photos', max_images=1)
urls[0]
# Out:
# Searching for 'bird photos'
# 'http://hdqwalls.com/download/1/colorful-parrot-bird.jpg'

# %% [markdown]
# ...and then download a URL and take a look at it:

# %%
from fastdownload import download_url
dest = 'bird.jpg'
download_url(urls[0], dest, show_progress=False)

from fastai.vision.all import *
im = Image.open(dest)
im.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=256x144>

# %% [markdown]
# Now let's do the same with "forest photos":

# %%
download_url(search_images('forest photos', max_images=1)[0], 'forest.jpg', show_progress=False)
Image.open('forest.jpg').to_thumb(256,256)
# Out:
# Searching for 'forest photos'
# <PIL.Image.Image image mode=RGB size=256x170>

# %% [markdown]
# Our searches seem to be giving reasonable results, so let's grab a few examples of each of "bird" and "forest" photos, and save each group of photos to a different folder (I'm also trying to grab a range of lighting conditions here):

# %%
searches = 'forest','bird'
path = Path('bird_or_not')
from time import sleep

for o in searches:
    dest = (path/o)
    dest.mkdir(exist_ok=True, parents=True)
    download_images(dest, urls=search_images(f'{o} photo'))
    sleep(10)  # Pause between searches to avoid over-loading server
    download_images(dest, urls=search_images(f'{o} sun photo'))
    sleep(10)
    download_images(dest, urls=search_images(f'{o} shade photo'))
    sleep(10)
    resize_images(path/o, max_size=400, dest=path/o)
# Out:
# Searching for 'forest photo'
# Searching for 'forest sun photo'
# Searching for 'forest shade photo'
# Searching for 'bird photo'
# Searching for 'bird sun photo'
# Searching for 'bird shade photo'

# %%
print(path)
searches = 'forest','bird'

for imageType in searches:
    print(imageType)
    content = os.listdir(path/imageType)
    for element in content:
        print(element)
# Out:
# bird_or_not
# forest
# b9d3b14d-87e0-4d69-bcae-6c833dee6137.jpg
# 760203ee-ddf6-4f23-98ba-3acc02f6d089.jpg
# 85638e3a-d1ce-4886-97c4-41310066419e.jpg
# 7f05b96a-89f4-4ee4-b5b3-84afb0294e83.jpg
# 977eb99f-72b4-4f29-a48d-af42fa12c8b3.jpg
# e3761839-866f-4dd0-983e-6a6e42af8e5f.jpg
# 2b091b37-d104-4282-a251-de551e44e54a.jpg
# d73071bf-a567-4126-8ddf-54d6d76ad306.jpg
# c664c478-bcb1-43aa-94d5-9aa4191fabd8.jpg
# 3b4334b9-bdb1-4c12-8765-24cf2b326bc2.jpg
# 97dbb114-791a-4154-9ee2-09a0b5945b63.jpg
# b45b0cf7-0aa5-4f08-895d-2d1047ba5292.jpg
# 0744c58e-80ae-403e-a599-924f983acaba.jpg
# 04ab6c3b-bfce-417c-a788-b399ea88a599.jpg
# 310c3a42-fdef-4d11-8123-936ab8ff5616.jpg!d
# 9916beab-142b-435a-bf54-c8d55816f5ad.jpg
# 936a5124-9d5c-4aa8-ac7a-fbc3aa3c0bfd.jpg
# 7d71a02a-5284-4383-85da-e2e485a75117.jpg
# e431dbbc-5a4c-4008-b5f6-a35a3e9d950e.jpg
# da27b4e2-9913-4f12-89ca-8a0f33950b41.jpg
# cc5adbb3-bc4f-450a-be59-0c1bd866317e.jpg
# 9dddb2fc-4f8a-42ab-a34b-e4dd3716c3e0.jpg
# 0b878416-0b24-4e3f-b8ff-8f371d4e7771.jpg
# d54f4add-70a4-479d-9d17-065131858676.jpg
# 08d35ad4-00f3-4667-8fb4-9d8e4b6a213f.jpg
# 3c19a35d-7c30-4c5f-9e13-ae4c3e269c4f.jpg
# 0746e71a-1a06-42c1-9f1d-62b1566d6c10.png
# 28da0f57-164a-418c-b575-5f24135f363a.jpg
# 7dcb1bde-bba9-41b3-9e0d-b1d4668a9907.jpg
# 9bddd8b0-63ed-4761-a6f2-d61770537ab5.jpg
# 1bc504f7-9b4c-4721-b89f-5ea976ec54f9.jpg
# 9b383348-23d5-472d-a8e7-606de8ea4e0d.jpg
# 9b69734f-1d6a-435b-ba2d-baf6c3f8289d.jpg
# 244e85a2-2787-4205-8e48-d1a2d2352d30.jpg
# 6beb509b-3bd2-4eb0-9b85-507942b6c472.jpg
# e6ee9f0b-588b-4bf9-ad3c-b297aef0473d.jpg
# 3d485eaf-86c6-411c-9601-f878e3b4acf4.jpg
# 87a3080e-d423-4e00-bc0b-68c6ed1ff7c5.jpg
# 1f68ef9e-7093-42b5-bfb7-0830b4a1a82e.jpg
# 8952a855-3ac6-4345-8cb7-6d6fc5a72a37.jpg
# 3e651949-529d-4f42-abdf-d799c42b470d.jpg
# 3a3f89e1-dd86-4720-bd46-7e031053d17c.jpg
# 2a7db52c-6850-4434-a7f0-cb29df34ee23.jpg

# %% [markdown]
# ## Step 2: Train our model

# %% [markdown]
# Some photos might not download correctly which could cause our model training to fail, so we'll remove them:

# %%
failed = verify_images(get_image_files(path))
failed.map(Path.unlink)
len(failed)
# Out:
# 7

# %% [markdown]
# To train a model, we'll need `DataLoaders`, which is an object that contains a *training set* (the images used to create a model) and a *validation set* (the images used to check the accuracy of a model -- not used during training). In `fastai` we can create that easily using a `DataBlock`, and view sample images from it:

# %%
dls = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=[Resize(192, method='squish')]
).dataloaders(path, bs=32)

dls.show_batch(max_n=6)
# Out:
# /home/asthanaamish/miniconda3/lib/python3.11/site-packages/fastai/torch_core.py:263: UserWarning: 'has_mps' is deprecated, please use 'torch.backends.mps.is_built()'
#   return getattr(torch, 'has_mps', False)

# %% [markdown]
# Here what each of the `DataBlock` parameters means:
#
#     blocks=(ImageBlock, CategoryBlock),
#
# The inputs to our model are images, and the outputs are categories (in this case, "bird" or "forest").
#
#     get_items=get_image_files,
#
# To find all the inputs to our model, run the `get_image_files` function (which returns a list of all image files in a path).
#
#     splitter=RandomSplitter(valid_pct=0.2, seed=42),
#
# Split the data into training and validation sets randomly, using 20% of the data for the validation set.
#
#     get_y=parent_label,
#
# The labels (`y` values) is the name of the `parent` of each file (i.e. the name of the folder they're in, which will be *bird* or *forest*).
#
#     item_tfms=[Resize(192, method='squish')]
#
# Before training, resize each image to 192x192 pixels by "squishing" it (as opposed to cropping it).

# %% [markdown]
# Now we're ready to train our model. The fastest widely used computer vision model is `resnet18`. You can train this in a few minutes, even on a CPU! (On a GPU, it generally takes under 10 seconds...)
#
# `fastai` comes with a helpful `fine_tune()` method which automatically uses best practices for fine tuning a pre-trained model, so we'll use that.

# %%
learn = vision_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(3)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /home/asthanaamish/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████████████████████████████████| 44.7M/44.7M [00:04<00:00, 9.58MB/s]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.829456</td>
#       <td>0.526205</td>
#       <td>0.242424</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.216303</td>
#       <td>0.210437</td>
#       <td>0.090909</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.136234</td>
#       <td>0.188556</td>
#       <td>0.090909</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.087929</td>
#       <td>0.135890</td>
#       <td>0.030303</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Generally when I run this I see 100% accuracy on the validation set (although it might vary a bit from run to run).
#
# "Fine-tuning" a model means that we're starting with a model someone else has trained using some other dataset (called the *pretrained model*), and adjusting the weights a little bit so that the model learns to recognise your particular dataset. In this case, the pretrained model was trained to recognise photos in *imagenet*, and widely-used computer vision dataset with images covering 1000 categories) For details on fine-tuning and why it's important, check out the [free fast.ai course](https://course.fast.ai/).

# %% [markdown]
# ## Step 3: Use our model (and build your own!)

# %% [markdown]
# Let's see what our model thinks about that bird we downloaded at the start:

# %%
is_bird,_,probs = learn.predict(PILImage.create('bird.jpg'))
print(f"This is a: {is_bird}.")
print(f"Probability it's a bird: {probs[0]:.4f}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# This is a: bird.
# Probability it's a bird: 0.9998

# %% [markdown]
# Good job, resnet18. :)
#
# So, as you see, in the space of a few years, creating computer vision classification models has gone from "so hard it's a joke" to "trivially easy and free"!
#
# It's not just in computer vision. Thanks to deep learning, computers can now do many things which seemed impossible just a few years ago, including [creating amazing artworks](https://openai.com/dall-e-2/), and [explaining jokes](https://www.datanami.com/2022/04/22/googles-massive-new-language-model-can-explain-jokes/). It's moving so fast that even experts in the field have trouble predicting how it's going to impact society in the coming years.
#
# One thing is clear -- it's important that we all do our best to understand this technology, because otherwise we'll get left behind!

# %% [markdown]
# Now it's your turn. Click "Copy & Edit" and try creating your own image classifier using your own image searches!
#
# If you enjoyed this, please consider clicking the "upvote" button in the top-right -- it's very encouraging to us notebook authors to know when people appreciate our work.
